# %%
import os
import pandas as pd
import numpy as np
import seaborn as sms

# %%
os.listdir('../derivatives/')
sub_df=pd.read_csv('../derivatives/OutlierRuns.tsv',sep='\t')

sub_df=sub_df[sub_df['outlier_run']==False]
sub_df['sub_run']=sub_df['Sub']+'_'+sub_df['run'].astype('str')
sub_df.head()
# Out:
#         Sub task  run       tsnr   fd_mean  outlier_run     sub_run
# 0  sub-1001  mid    1  69.988391  0.149729        False  sub-1001_1
# 1  sub-1001  mid    2  55.697644  0.184703        False  sub-1001_2
# 2  sub-1002  mid    1  77.148079  0.111157        False  sub-1002_1
# 3  sub-1002  mid    2  90.519196  0.092381        False  sub-1002_2
# 4  sub-1003  mid    1  66.602654  0.171448        False  sub-1003_1

# %%
#Import the Libraries
import numpy as np
from scipy.io import loadmat  # this is the SciPy module that loads mat-files
import matplotlib.pyplot as plt
from datetime import datetime, date, time
import pandas as pd
import os
from natsort import natsorted
import re

#Make a list of the files
Mat_Beh_dir='/data/projects/istart/Monetary_Incentive/data'
ML_EvFiles_list=natsorted([os.path.join(root,f) for root,dirs,files in os.walk(
    Mat_Beh_dir) for f in files if 'run' in f])

print("The number of Subjects are: %s"%(len([x for x in os.listdir(Mat_Beh_dir) if x.startswith('sub')])))
print("The number of files are: %s"%(len(ML_EvFiles_list)))
print("----------------------------------------")
#Make Conditions for Run1 and Run2
run_cond=loadmat('%s/../timing/run1.mat'%(Mat_Beh_dir))
run1=run_cond['run']['cond'][0,0]
run1 = np.where(run1==['1'], 'Large_gain', run1)
run1 = np.where(run1==[1], 'Large_gain', run1)
run1 = np.where(run1==['2'], 'Large_loss', run1)
run1 = np.where(run1==['3'], 'Small_gain', run1)
run1 = np.where(run1==['4'], 'Small_loss', run1)
run1 = np.where(run1==['5'], 'Neutral', run1)
run1=np.concatenate(run1)

run_cond=loadmat('%s/../timing/run2.mat'%(Mat_Beh_dir))
run2=run_cond['run']['cond'][0,0]
run2 = np.where(run2==[1], 'Large_gain', run2)
run2 = np.where(run2==['1'], 'Large_gain', run2)
run2 = np.where(run2==['2'], 'Large_loss', run2)
run2 = np.where(run2==['3'], 'Small_gain', run2)
run2 = np.where(run2==['4'], 'Small_loss', run2)
run2 = np.where(run2==['5'], 'Neutral', run2)
run2=np.concatenate(run2)
# Out:
# The number of Subjects are: 60
# The number of files are: 83
# ----------------------------------------
# /tmp/ipykernel_3914331/2876148422.py:22: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   run1 = np.where(run1==['1'], 'Large_gain', run1)
# /tmp/ipykernel_3914331/2876148422.py:23: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   run1 = np.where(run1==[1], 'Large_gain', run1)

# %%
display(ML_EvFiles_list)
# Out:
# ['/data/projects/istart/Monetary_Incentive/data/sub-1001/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1001/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1002/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1002/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1003/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1004/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1004/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1006/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1007/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1007/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1009/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1009/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1010/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1010/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1011/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1011/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1012/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1012/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1013/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1013/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1015/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1015/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1016/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1016/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1019/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1019/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1021/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1021/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1242/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1243/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1243/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1244/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1244/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1245/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1245/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1247/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1247/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1248/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1248/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1249/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1249/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1253/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1253/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1255/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1255/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1276/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1282/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1285/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1286/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1294/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1300/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1300/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1301/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1301/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1302/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1303/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1999/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-1999/run-2_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3101/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3116/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3122/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3125/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3140/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3143/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3152/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3164/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3166/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3167/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3170/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3173/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3175/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3176/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3186/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3189/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3190/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3199/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3200/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3206/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3210/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3212/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3218/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3220/run-1_output.mat',
#  '/data/projects/istart/Monetary_Incentive/data/sub-3223/run-1_output.mat']

# %%
data_dir='/data/projects/istart/Monetary_Incentive/'
len(os.listdir('%s/bids_archive/bids'%(data_dir)))
# Out:
# 48

# %%
len(sub_df['Sub'].unique())
# Out:
# 51

# %%
data=[]
for ML_EvFile in ML_EvFiles_list:
    #print(ML_EvFile)
    sub='sub-'+re.search('sub-(.*)/',ML_EvFile).group(1)
    run=re.search('run-(.*)_out',ML_EvFile).group(1)
    #if sub+'_'+run in sub_df['sub_run'].values:
    #print(sub,run)
    mat = loadmat(ML_EvFile)  # load mat-file
    mdata = mat['output']  # variable in mat file
    mdtype = mdata.dtype  # dtypes of structures are "unsized objects"
    # * SciiencPy reads in structures as structureprintd NumPy arrays of dtype object
    # * The size of the array is the size of the structure array, not the number
    #   elements in any particular field. The shape defaults to 2-dimensional.
    # * For convene make a dictionary of the data using the names from dtypes
    # * Since the structure has only one element, but is 2-D, index it at [0, 0]
    ndata = {n: mdata[n][0, 0] for n in mdtype.names}
    # Reconstruct the columns of the data table from just the time series
    # Use the number of intervals to test if a field is a column or metadata
    columns = [n for n in ndata]
    #Check fo frame
    # now make a data frame, setting the time stamps as the index
    lens=[len(x[0]) for x in ndata.values()]
    if lens.count(lens[0]) == len(lens):
        df = pd.DataFrame(np.transpose(np.concatenate([ndata[c] for c in columns])),
                  columns=columns)
        if run=='1':
            if len(df)==50:
                df['trial_type']=run1[0:50]
            elif len(df)==75:
                df['trial_type']=run1
        if run=='2':
            df['trial_type']=run2
        df['sub']=sub
        df['run']=run
        data.append(df)
df=pd.concat(data)

# %%
sms.histplot(x=df['RT'])
# Out:
# <AxesSubplot:xlabel='RT', ylabel='Count'>

# %%
misses=[]
for sub in df['sub'].unique():
    tmp=df[df['sub']==sub]
    for run in tmp['run'].unique():
        tmp=tmp[tmp['run']==run]
        misses.append(len(tmp[(tmp['RT']==0)&(tmp['outcome']==0)]))

# %%
print(" The largest number of missed trials is %s this is less than 20 percent of trials"%(np.max(misses)))
# Out:
#  The largest number of missed trials is 6 this is less than 20 percent of trials

# %%
df.loc[df["trial_type"] == "1", "trial_type"] = "Large_gain"
df['run']=df['run'].astype(int)
df.groupby(by=['sub','run']).max().reset_index()
# Out:
#          sub  run  outcome  trial_starts  target_starts        RT    thresh  \
# 0   sub-1001    1      1.0    443.596841     445.607023  0.690546  0.584389
# 1   sub-1001    2      1.0    450.916843     454.927744  0.846985  0.511823
# 2   sub-1002    1      1.0    443.595531     445.605782  0.491392  0.464767
# 3   sub-1002    2      1.0    450.928644     454.939221  0.571258  0.466639
# 4   sub-1003    1      1.0    443.546470     445.555652  0.738533  0.496835
# ..       ...  ...      ...           ...            ...       ...       ...
# 75  sub-3210    1      1.0    679.768941     682.773112  0.823762  0.458219
# 76  sub-3212    1      1.0    679.607846     682.610161  0.857764  0.456245
# 77  sub-3218    1      1.0    679.653301     682.655712  0.557942  0.466697
# 78  sub-3220    1      1.0    679.645557     682.648115  0.922452  0.596440
# 79  sub-3223    1      1.0    679.645179     682.647789  0.853139  0.642084
#
#     trial_type
# 0   Small_loss
# 1   Small_loss
# 2   Small_loss
# 3   Small_loss
# 4   Small_loss
# ..         ...
# 75  Small_loss
# 76  Small_loss
# 77  Small_loss
# 78  Small_loss
# 79  Small_loss
#
# [80 rows x 8 columns]

# %%
no_miss=df[(df['RT']>0.001)]
no_miss[no_miss['RT']==0]
df=no_miss

# %%
sms.histplot(x=df['RT'])
# Out:
# <AxesSubplot:xlabel='RT', ylabel='Count'>

# %%
df.loc[df["trial_type"] == "1", "trial_type"] = "Large_gain"

df['Trial_code']=df['trial_type'].map({"Large_loss":-2,"Small_loss":-1,"Neutral":0,"Small_gain":1,"Large_gain":2})
df['Trial_code'].unique()
# Out:
# array([-1,  0, -2,  2,  1])

# %%
df[df['sub']=='sub-3199']
# Out:
#     outcome  trial_starts  target_starts        RT    thresh  trial_type  \
# 0       1.0      4.005512       6.007814  0.317093  0.354215  Small_loss
# 1       1.0     10.013537      12.015883  0.208390  0.359615     Neutral
# 2       1.0     20.824335      24.826691  0.347995  0.405430  Large_loss
# 3       0.0     30.432088      33.435449  0.476594  0.469060  Large_loss
# 4       0.0     38.880598      42.884209  0.412769  0.433266  Large_gain
# ..      ...           ...            ...       ...       ...         ...
# 70      0.0    639.997196     643.999625  0.329608  0.338173  Small_gain
# 71      0.0    656.809263     658.811312  0.436908  0.383256  Small_gain
# 72      1.0    664.016155     667.018345  0.042789  0.324323  Small_loss
# 73      1.0    670.022225     674.024309  0.380891  0.478732  Small_gain
# 74      1.0    679.628384     682.630698  0.266379  0.341087  Small_loss
#
#          sub  run  Trial_code
# 0   sub-3199    1          -1
# 1   sub-3199    1           0
# 2   sub-3199    1          -2
# 3   sub-3199    1          -2
# 4   sub-3199    1           2
# ..       ...  ...         ...
# 70  sub-3199    1           1
# 71  sub-3199    1           1
# 72  sub-3199    1          -1
# 73  sub-3199    1           1
# 74  sub-3199    1          -1
#
# [70 rows x 9 columns]

# %%
df['run']=df['run'].astype(int)
group_df=df.groupby(by=['sub','trial_type']).median()
group_df=group_df.reset_index()
display(group_df.head())
sms.barplot(x='Trial_code',y='RT',data=group_df,ci=68)
# Out:
#         sub  trial_type  outcome  trial_starts  target_starts        RT  \
# 0  sub-1001  Large_gain      1.0    246.980226     249.991329  0.305435
# 1  sub-1001  Large_loss      1.0    185.605540     188.116553  0.308371
# 2  sub-1001     Neutral      1.0    207.873973     209.884223  0.332187
# 3  sub-1001  Small_gain      1.0    281.873566     285.883902  0.320507
# 4  sub-1001  Small_loss      1.0    156.110382     159.620759  0.362250
#
#      thresh  run  Trial_code
# 0  0.418198  1.5         2.0
# 1  0.411154  1.5        -2.0
# 2  0.443540  1.5         0.0
# 3  0.376292  1.5         1.0
# 4  0.426017  1.5        -1.0
# /tmp/ipykernel_3914331/1342539350.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sms.barplot(x='Trial_code',y='RT',data=group_df,ci=68)
# <AxesSubplot:xlabel='Trial_code', ylabel='RT'>

# %%
from scipy.stats import ttest_rel
print("Is the Mean RT difference between large and small gains significant")
ttest_rel(group_df[group_df['trial_type']=='Large_gain']['RT'],
         group_df[group_df['trial_type']=='Neutral']['RT'])
# Out:
# Is the Mean RT difference between large and small gains significant
# Ttest_relResult(statistic=-2.251152182654499, pvalue=0.028319069718487837)

# %%
print("Is the Mean RT difference between large and small losses significant")

ttest_rel(group_df[group_df['trial_type']=='Large_loss']['RT'],
         group_df[group_df['trial_type']=='Neutral']['RT'])
# Out:
# Is the Mean RT difference between large and small losses significant
# Ttest_relResult(statistic=-1.3234223400153604, pvalue=0.19107281277351285)

# %%
import numpy as np

data=[]
#polynomial fit with degree = 2
for sub in group_df['sub'].unique():
    tmp=group_df[group_df['sub']==sub]
    LG_RT=tmp[tmp['trial_type']=="Large_gain"]['RT'].values[0]
    LL_RT=tmp[tmp['trial_type']=="Large_loss"]['RT'].values[0]
    Neu_RT=tmp[tmp['trial_type']=="Neutral"]['RT'].values[0]
    model = np.poly1d(np.polyfit(tmp['Trial_code'].values, tmp['RT'].values, 2))
    
    data.append([sub,model[2],
                 LG_RT-Neu_RT,
                 LL_RT-Neu_RT,
                 (LG_RT-Neu_RT)-(LL_RT-Neu_RT)
                ])
Fits=pd.DataFrame(columns=['Sub','V_beta','LG-N','LL-N',"rel_rew"],data=data)

# %%
Fits.to_csv('../derivatives/Fits_of_RT.csv',index=False)

# %%
Fits
# Out:
#          Sub    V_beta      LG-N      LL-N   rel_rew
# 0   sub-1001 -0.008537 -0.026752 -0.023816 -0.002937
# 1   sub-1002 -0.013022 -0.072843 -0.063259 -0.009585
# 2   sub-1003 -0.000617  0.054024 -0.014524  0.068547
# 3   sub-1004 -0.002456  0.020756 -0.019793  0.040550
# 4   sub-1006 -0.005296 -0.023401 -0.022996 -0.000405
# 5   sub-1007  0.003755  0.013241  0.053518 -0.040277
# 6   sub-1009 -0.001678 -0.014629 -0.007453 -0.007177
# 7   sub-1010 -0.004302 -0.014965  0.004005 -0.018970
# 8   sub-1011 -0.007221 -0.042208 -0.023506 -0.018702
# 9   sub-1012 -0.006041 -0.022781 -0.059955  0.037174
# 10  sub-1013 -0.005111 -0.017062 -0.018792  0.001730
# 11  sub-1015 -0.007821 -0.011908 -0.011626 -0.000282
# 12  sub-1016 -0.001875 -0.008568 -0.004527 -0.004040
# 13  sub-1019 -0.008120 -0.017512 -0.016865 -0.000646
# 14  sub-1021  0.000351  0.073252 -0.007254  0.080506
# 15  sub-1242 -0.001666 -0.014214  0.012443 -0.026657
# 16  sub-1243 -0.002573 -0.018545 -0.006432 -0.012112
# 17  sub-1244  0.001281 -0.035078  0.011088 -0.046166
# 18  sub-1245 -0.004766 -0.043319 -0.027058 -0.016261
# 19  sub-1247  0.002062  0.003597  0.005625 -0.002027
# 20  sub-1248 -0.004329 -0.027203 -0.019562 -0.007641
# 21  sub-1249  0.001181  0.003854  0.005782 -0.001928
# 22  sub-1253  0.010099  0.105324  0.035401  0.069923
# 23  sub-1255 -0.020217 -0.149253 -0.142915 -0.006338
# 24  sub-1276  0.002861  0.006231  0.021662 -0.015431
# 25  sub-1282  0.006357  0.035044  0.031921  0.003123
# 26  sub-1285  0.009230  0.011540  0.037370 -0.025830
# 27  sub-1286  0.013804  0.076968  0.033975  0.042993
# 28  sub-1294  0.010483  0.064827  0.053104  0.011724
# 29  sub-1300 -0.002862 -0.017731  0.014823 -0.032554
# 30  sub-1301 -0.003369  0.001468 -0.007478  0.008946
# 31  sub-1302  0.002761  0.000436  0.000854 -0.000418
# 32  sub-1303 -0.007603 -0.032821 -0.015223 -0.017599
# 33  sub-1999  0.033251  0.098005  0.356087 -0.258083
# 34  sub-3116  0.000578  0.005838 -0.016690  0.022528
# 35  sub-3125 -0.000191 -0.009883 -0.006330 -0.003553
# 36  sub-3140 -0.014376 -0.026763 -0.111708  0.084945
# 37  sub-3143 -0.010618 -0.055414 -0.065438  0.010023
# 38  sub-3152  0.000418  0.003979  0.000177  0.003802
# 39  sub-3164  0.013858  0.064918  0.071693 -0.006775
# 40  sub-3166 -0.004652 -0.063505 -0.041108 -0.022397
# 41  sub-3167 -0.002119 -0.050899 -0.009486 -0.041412
# 42  sub-3170  0.000127  0.002906  0.010100 -0.007194
# 43  sub-3173  0.001178  0.004868  0.011023 -0.006156
# 44  sub-3175 -0.012565 -0.107345 -0.094752 -0.012593
# 45  sub-3176  0.001186  0.012137 -0.000799  0.012936
# 46  sub-3186 -0.011595 -0.054646 -0.041934 -0.012712
# 47  sub-3189 -0.001566 -0.008640 -0.010015  0.001375
# 48  sub-3190 -0.024801 -0.146340 -0.079127 -0.067212
# 49  sub-3199 -0.035781 -0.254578 -0.182376 -0.072202
# 50  sub-3200 -0.004291 -0.014804 -0.025678  0.010874
# 51  sub-3206 -0.025722 -0.135220 -0.117862 -0.017358
# 52  sub-3210  0.008831 -0.013413 -0.008440 -0.004973
# 53  sub-3212 -0.017072 -0.051148 -0.048118 -0.003030
# 54  sub-3218 -0.001526 -0.000916 -0.022112  0.021196
# 55  sub-3220 -0.017514 -0.019896 -0.026286  0.006390
# 56  sub-3223 -0.017603 -0.060017 -0.025304 -0.034713

# %%
per_df=pd.read_excel('../derivatives/covariates/final_output_composite_wfnames.xls')
per_df['Subject']='sub-'+per_df['Subject'].astype('str')
per_df
# Out:
#                                               Subject  \
# 0                                            sub-1001
# 1                                            sub-1003
# 2                                            sub-1004
# 3                                            sub-1006
# 4                                            sub-1009
# 5                                            sub-1010
# 6                                            sub-1011
# 7                                            sub-1012
# 8                                            sub-1013
# 9                                            sub-1015
# 10                                           sub-1016
# 11                                           sub-1019
# 12                                           sub-1021
# 13                                           sub-1242
# 14                                           sub-1243
# 15                                           sub-1244
# 16                                           sub-1245
# 17                                           sub-1247
# 18                                           sub-1248
# 19                                           sub-1249
# 20                                           sub-1255
# 21                                           sub-1276
# 22                                           sub-1282
# 23                                           sub-1286
# 24                                           sub-1294
# 25                                           sub-1300
# 26                                           sub-1301
# 27                                           sub-1302
# 28                                           sub-1303
# 29                                           sub-3116
# 30                                           sub-3125
# 31                                           sub-3140
# 32                                           sub-3143
# 33                                           sub-3166
# 34                                           sub-3167
# 35                                           sub-3170
# 36                                           sub-3173
# 37                                           sub-3175
# 38                                           sub-3176
# 39                                           sub-3189
# 40                                           sub-3190
# 41                                           sub-3199
# 42                                           sub-3200
# 43                                           sub-3206
# 44                                           sub-3212
# 45                                           sub-3218
# 46                                           sub-3220
# 47                                            sub-nan
# 48                                            sub-nan
# 49                                            sub-nan
# 50                                            sub-nan
# 51                                            sub-nan
# 52  sub-NOTE: THESE SUBJECTS HAD LESS THAN 50 feed...
# 53                                           sub-3101
# 54                                           sub-3122
#
#                                            Fnames-act  Fnames-ppi  Ones  \
# 0   /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 1   /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 2   /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 3   /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 4   /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 5   /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 6   /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 7   /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 8   /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 9   /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 10  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 11  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 12  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 13  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 14  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 15  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 16  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 17  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 18  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 19  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 20  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 21  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 22  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 23  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 24  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 25  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 26  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 27  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 28  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 29  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 30  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 31  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 32  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 33  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 34  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 35  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 36  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 37  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 38  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 39  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 40  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 41  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 42  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 43  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 44  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 45  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 46  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 47                                                NaN         NaN   NaN
# 48                                                NaN         NaN   NaN
# 49                                                NaN         NaN   NaN
# 50                                                NaN         NaN   NaN
# 51                                                NaN         NaN   NaN
# 52                                                NaN         NaN   NaN
# 53                                                NaN         NaN   1.0
# 54                                                NaN         NaN   1.0
#
#     Composite_Substance  Composite_Reward  Composite_Reward_Squared      tsnr  \
# 0              0.534825          0.469388                 -8.028738 -0.379745
# 1              0.044818          0.469388                 -8.028738 -0.114737
# 2             -0.249186          2.469388                 -2.151187 -0.076754
# 3             -1.131198         -0.530612                 -7.967514  1.360129
# 4             -1.131198          1.469388                 -6.089963  1.238442
# 5              3.340563         -1.530612                 -5.906289 -0.480247
# 6             -1.425202          2.469388                 -2.151187 -0.049279
# 7             -1.425202         -4.530612                 12.277384  1.950944
# 8             -0.771860          4.469388                 11.726364  1.707433
# 9              2.396851         -3.530612                  4.216160  0.807888
# 10            -1.131198          3.469388                  3.787589  1.348852
# 11             0.044818          2.469388                 -2.151187 -0.121838
# 12            -0.543190         -1.530612                 -5.906289  0.181632
# 13             1.514839          2.469388                 -2.151187 -0.100809
# 14            -0.543190         -2.530612                 -1.845065 -0.142273
# 15             1.444961          4.469388                 11.726364  0.092840
# 16             0.075668         -3.530612                  4.216160  0.152752
# 17            -0.543190          3.469388                  3.787589 -1.067944
# 18            -1.425202          2.469388                 -2.151187  1.472521
# 19            -0.055909          1.469388                 -6.089963  0.014971
# 20             0.338823         -1.530612                 -5.906289 -0.108164
# 21            -1.425202         -2.530612                 -1.845065 -0.742961
# 22             0.562949          4.469388                 11.726364  1.405488
# 23            -0.837194         -0.530612                 -7.967514 -1.222841
# 24            -1.131198         -2.530612                 -1.845065 -1.067010
# 25            -1.131198         -4.530612                 12.277384 -1.656919
# 26             0.044818         -2.530612                 -1.845065 -0.267637
# 27             0.988530          4.469388                 11.726364 -0.492371
# 28             2.783405          0.469388                 -8.028738 -0.614070
# 29            -0.837194          1.469388                 -6.089963  0.708388
# 30            -0.055909          4.469388                 11.726364 -1.414182
# 31             0.208154         -1.530612                 -5.906289 -0.449731
# 32             5.637211          0.469388                 -8.028738 -0.403876
# 33            -0.512340         -3.530612                  4.216160  0.801156
# 34            -1.131198         -2.530612                 -1.845065  0.832181
# 35            -1.425202         -4.530612                 12.277384  1.607807
# 36            -1.131198          3.469388                  3.787589  0.417980
# 37            -1.425202         -4.530612                 12.277384 -1.294347
# 38             0.532099         -3.530612                  4.216160  0.196223
# 39             0.005790         -0.530612                 -7.967514  0.421830
# 40            -0.643917          3.469388                  3.787589 -0.861373
# 41            -0.543190          1.469388                 -6.089963  1.168177
# 42            -1.425202         -3.530612                  4.216160  0.432345
# 43             1.800665         -1.530612                 -5.906289 -1.563364
# 44            -1.425202         -3.530612                  4.216160  0.942059
# 45             5.080053          0.469388                 -8.028738 -1.601156
# 46             0.044818          1.469388                 -6.089963 -2.160814
# 47                  NaN               NaN                       NaN       NaN
# 48                  NaN               NaN                       NaN       NaN
# 49             0.580985               NaN                       NaN       NaN
# 50                  NaN               NaN                       NaN       NaN
# 51                  NaN               NaN                       NaN       NaN
# 52                  NaN               NaN                       NaN       NaN
# 53            -0.543190         -0.530612                 -7.967514 -1.460024
# 54            -1.425202          3.469388                  3.787589 -0.873847
#
#      fd_mean  Composite_SubstanceXReward  Composite_SubstanceXReward_Squared  \
# 0   0.030117                   -0.191576                            3.342227
# 1   0.105981                   -0.421580                            3.234266
# 2  -0.474856                   -1.057953                            1.704889
# 3  -0.870765                    0.157611                            2.905903
# 4   0.036518                   -2.104785                            0.782022
# 5   0.055851                   -5.555724                           11.050575
# 6   0.495952                   -3.961993                           -5.466314
# 7  -1.066111                    6.014421                          -26.029944
# 8  -1.317167                   -3.892357                          -12.193833
# 9   0.215301                   -8.904970                           33.101678
# 10 -0.756184                   -4.367181                          -10.391444
# 11 -0.103825                   -0.331943                            3.497689
# 12 -0.202612                    0.388796                            1.951821
# 13 -1.037998                    3.298108                           12.461692
# 14  2.921899                    0.931986                           -0.254195
# 15  1.029422                    6.015475                           32.088110
# 16 -0.754424                   -0.709772                            4.167612
# 17  1.092103                   -2.327153                           -3.313794
# 18 -0.944581                   -3.961993                           -5.466314
# 19  0.820356                   -0.524769                            3.103678
# 20 -0.161144                   -0.961223                            4.018176
# 21 -0.108177                    3.164017                           -5.902600
# 22 -1.141454                    2.073420                           14.469537
# 23 -0.313432                    0.001608                            2.988680
# 24 -0.262262                    2.420007                           -4.019798
# 25  1.671487                    4.682402                          -19.995084
# 26  1.187733                   -0.556035                            3.511409
# 27 -0.224880                    3.975508                           22.970705
# 28 -0.300417                    0.863879                            3.837645
# 29 -0.169604                   -1.672779                            1.416806
# 30  2.670892                   -0.692496                            2.107585
# 31  0.819021                   -0.761220                            3.712050
# 32 -0.766803                    2.203421                            4.466409
# 33 -0.172097                    1.366257                           -3.162041
# 34  0.738754                    2.420007                           -4.019798
# 35 -1.436902                    6.014421                          -26.029944
# 36 -1.358877                   -4.367181                          -10.391444
# 37  1.279608                    6.014421                          -26.029944
# 38  0.513570                   -2.321253                            9.857127
# 39 -0.748219                   -0.445689                            3.226022
# 40  0.008779                   -2.676615                           -4.526216
# 41 -0.443655                   -1.240773                            2.051590
# 42 -0.245945                    4.589219                          -14.541070
# 43  1.778171                   -3.198736                            7.442942
# 44 -1.900885                    4.589219                          -14.541070
# 45 -0.249590                    1.941898                            4.343653
# 46  1.037055                   -0.376761                            3.321159
# 47       NaN                         NaN                                 NaN
# 48       NaN                         NaN                                 NaN
# 49       NaN                   -0.316299                                 NaN
# 50       NaN                         NaN                                 NaN
# 51       NaN                         NaN                                 NaN
# 52       NaN                         NaN                                 NaN
# 53  0.981210                   -0.154394                            3.071457
# 54 -0.076958                   -5.387195                          -13.930269
#
#     Unnamed: 11  Unnamed: 12  fd_mean.1
# 0           NaN          NaN  -0.334966
# 1           NaN          NaN   1.517712
# 2           NaN          NaN  -0.364555
# 3           NaN          NaN  -0.883898
# 4           NaN          NaN  -0.290715
# 5           NaN          NaN   0.600550
# 6           NaN          NaN   1.575204
# 7           NaN          NaN  -0.500486
# 8           NaN          NaN  -1.249693
# 9           NaN          NaN   0.048934
# 10          NaN          NaN  -0.862482
# 11          NaN          NaN  -0.010148
# 12          NaN          NaN   0.418005
# 13          NaN          NaN  -1.082686
# 14          NaN          NaN   2.743835
# 15          NaN          NaN   0.897171
# 16          NaN          NaN  -0.764871
# 17          NaN          NaN   1.480574
# 18          NaN          NaN   0.006603
# 19          NaN          NaN  -0.303872
# 20          NaN          NaN  -1.251559
# 21          NaN          NaN  -0.540060
# 22          NaN          NaN  -0.524767
# 23          NaN          NaN   1.050020
# 24          NaN          NaN  -0.508952
# 25          NaN          NaN  -0.320873
# 26          NaN          NaN   1.426223
# 27          NaN          NaN  -0.706137
# 28          NaN          NaN   2.058890
# 29          NaN          NaN   0.096755
# 30          NaN          NaN  -0.197272
# 31          NaN          NaN   0.740366
# 32          NaN          NaN  -1.198608
# 33          NaN          NaN  -1.101942
# 34          NaN          NaN   0.694740
# 35          NaN          NaN  -0.748881
# 36          NaN          NaN  -0.129887
# 37          NaN          NaN  -0.083709
# 38          NaN          NaN  -0.382951
# 39          NaN          NaN  -0.267491
# 40          NaN          NaN   0.340697
# 41          NaN          NaN  -1.692667
# 42          NaN          NaN   1.106793
# 43          NaN          NaN   0.250391
# 44          NaN          NaN        NaN
# 45          NaN          NaN        NaN
# 46          NaN          NaN        NaN
# 47          NaN          NaN        NaN
# 48          NaN          NaN        NaN
# 49          NaN          NaN        NaN
# 50          NaN          NaN        NaN
# 51          NaN          NaN        NaN
# 52          NaN          NaN        NaN
# 53          NaN          NaN  -0.096688
# 54          NaN          NaN   2.245947

# %%
total_df=pd.merge(Fits, per_df, how='left', left_on=['Sub'], right_on=['Subject'])
total_df.head()
# Out:
#         Sub    V_beta      LG-N      LL-N   rel_rew   Subject  \
# 0  sub-1001 -0.008537 -0.026752 -0.023816 -0.002937  sub-1001
# 1  sub-1002 -0.013022 -0.072843 -0.063259 -0.009585       NaN
# 2  sub-1003 -0.000617  0.054024 -0.014524  0.068547  sub-1003
# 3  sub-1004 -0.002456  0.020756 -0.019793  0.040550  sub-1004
# 4  sub-1006 -0.005296 -0.023401 -0.022996 -0.000405  sub-1006
#
#                                           Fnames-act  Fnames-ppi  Ones  \
# 0  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 1                                                NaN         NaN   NaN
# 2  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 3  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 4  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
#
#    Composite_Substance  Composite_Reward  Composite_Reward_Squared      tsnr  \
# 0             0.534825          0.469388                 -8.028738 -0.379745
# 1                  NaN               NaN                       NaN       NaN
# 2             0.044818          0.469388                 -8.028738 -0.114737
# 3            -0.249186          2.469388                 -2.151187 -0.076754
# 4            -1.131198         -0.530612                 -7.967514  1.360129
#
#     fd_mean  Composite_SubstanceXReward  Composite_SubstanceXReward_Squared  \
# 0  0.030117                   -0.191576                            3.342227
# 1       NaN                         NaN                                 NaN
# 2  0.105981                   -0.421580                            3.234266
# 3 -0.474856                   -1.057953                            1.704889
# 4 -0.870765                    0.157611                            2.905903
#
#    Unnamed: 11  Unnamed: 12  fd_mean.1
# 0          NaN          NaN  -0.334966
# 1          NaN          NaN        NaN
# 2          NaN          NaN   1.517712
# 3          NaN          NaN  -0.364555
# 4          NaN          NaN  -0.883898

# %%
from scipy.stats import pearsonr,kendalltau
responses=['V_beta','LG-N','LL-N']#'rel_rew']

total_df=total_df[~total_df['Composite_Reward'].isna()]

for resp in responses:
    sms.lmplot(x='Composite_Reward',y=resp,data=total_df,order=1)
    
    plt.show()
    r,p=pearsonr(total_df['Composite_Reward'],total_df[resp])
    print('r:  %s p: %s'%(r,p))
for resp in responses:
    sms.lmplot(x='Composite_Reward',y=resp,data=total_df,order=2)
    plt.show()
    r,p=pearsonr(total_df['Composite_Reward_Squared'],total_df[resp])
    print('r:  %s p: %s'%(r,p))
# Out:
# r:  0.07094064764311481 p: 0.6356095594366742
# r:  0.03662788248450071 p: 0.8068991043070649
# r:  0.1302515500803995 p: 0.38285919112029354
# r:  0.1650454715560881 p: 0.26758103765618757
# r:  0.01184611846576336 p: 0.9370097651449026
# r:  0.17305485241186283 p: 0.24472429633579051

# %%
per_df
# Out:
#                                               Subject  \
# 0                                            sub-1001
# 1                                            sub-1003
# 2                                            sub-1004
# 3                                            sub-1006
# 4                                            sub-1009
# 5                                            sub-1010
# 6                                            sub-1011
# 7                                            sub-1012
# 8                                            sub-1013
# 9                                            sub-1015
# 10                                           sub-1016
# 11                                           sub-1019
# 12                                           sub-1021
# 13                                           sub-1242
# 14                                           sub-1243
# 15                                           sub-1244
# 16                                           sub-1245
# 17                                           sub-1247
# 18                                           sub-1248
# 19                                           sub-1249
# 20                                           sub-1255
# 21                                           sub-1276
# 22                                           sub-1282
# 23                                           sub-1286
# 24                                           sub-1294
# 25                                           sub-1300
# 26                                           sub-1301
# 27                                           sub-1302
# 28                                           sub-1303
# 29                                           sub-3116
# 30                                           sub-3125
# 31                                           sub-3140
# 32                                           sub-3143
# 33                                           sub-3166
# 34                                           sub-3167
# 35                                           sub-3170
# 36                                           sub-3173
# 37                                           sub-3175
# 38                                           sub-3176
# 39                                           sub-3189
# 40                                           sub-3190
# 41                                           sub-3199
# 42                                           sub-3200
# 43                                           sub-3206
# 44                                           sub-3212
# 45                                           sub-3218
# 46                                           sub-3220
# 47                                            sub-nan
# 48                                            sub-nan
# 49                                            sub-nan
# 50                                            sub-nan
# 51                                            sub-nan
# 52  sub-NOTE: THESE SUBJECTS HAD LESS THAN 50 feed...
# 53                                           sub-3101
# 54                                           sub-3122
#
#                                            Fnames-act  Fnames-ppi  Ones  \
# 0   /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 1   /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 2   /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 3   /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 4   /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 5   /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 6   /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 7   /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 8   /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 9   /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 10  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 11  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 12  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 13  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 14  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 15  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 16  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 17  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 18  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 19  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 20  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 21  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 22  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 23  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 24  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 25  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 26  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 27  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 28  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 29  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 30  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 31  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 32  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 33  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 34  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 35  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 36  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 37  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 38  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 39  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 40  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 41  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 42  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 43  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 44  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 45  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 46  /data/projects/istart-mid/derivatives/fsl/sub-...         NaN   1.0
# 47                                                NaN         NaN   NaN
# 48                                                NaN         NaN   NaN
# 49                                                NaN         NaN   NaN
# 50                                                NaN         NaN   NaN
# 51                                                NaN         NaN   NaN
# 52                                                NaN         NaN   NaN
# 53                                                NaN         NaN   1.0
# 54                                                NaN         NaN   1.0
#
#     Composite_Substance  Composite_Reward  Composite_Reward_Squared      tsnr  \
# 0              0.534825          0.469388                 -8.028738 -0.379745
# 1              0.044818          0.469388                 -8.028738 -0.114737
# 2             -0.249186          2.469388                 -2.151187 -0.076754
# 3             -1.131198         -0.530612                 -7.967514  1.360129
# 4             -1.131198          1.469388                 -6.089963  1.238442
# 5              3.340563         -1.530612                 -5.906289 -0.480247
# 6             -1.425202          2.469388                 -2.151187 -0.049279
# 7             -1.425202         -4.530612                 12.277384  1.950944
# 8             -0.771860          4.469388                 11.726364  1.707433
# 9              2.396851         -3.530612                  4.216160  0.807888
# 10            -1.131198          3.469388                  3.787589  1.348852
# 11             0.044818          2.469388                 -2.151187 -0.121838
# 12            -0.543190         -1.530612                 -5.906289  0.181632
# 13             1.514839          2.469388                 -2.151187 -0.100809
# 14            -0.543190         -2.530612                 -1.845065 -0.142273
# 15             1.444961          4.469388                 11.726364  0.092840
# 16             0.075668         -3.530612                  4.216160  0.152752
# 17            -0.543190          3.469388                  3.787589 -1.067944
# 18            -1.425202          2.469388                 -2.151187  1.472521
# 19            -0.055909          1.469388                 -6.089963  0.014971
# 20             0.338823         -1.530612                 -5.906289 -0.108164
# 21            -1.425202         -2.530612                 -1.845065 -0.742961
# 22             0.562949          4.469388                 11.726364  1.405488
# 23            -0.837194         -0.530612                 -7.967514 -1.222841
# 24            -1.131198         -2.530612                 -1.845065 -1.067010
# 25            -1.131198         -4.530612                 12.277384 -1.656919
# 26             0.044818         -2.530612                 -1.845065 -0.267637
# 27             0.988530          4.469388                 11.726364 -0.492371
# 28             2.783405          0.469388                 -8.028738 -0.614070
# 29            -0.837194          1.469388                 -6.089963  0.708388
# 30            -0.055909          4.469388                 11.726364 -1.414182
# 31             0.208154         -1.530612                 -5.906289 -0.449731
# 32             5.637211          0.469388                 -8.028738 -0.403876
# 33            -0.512340         -3.530612                  4.216160  0.801156
# 34            -1.131198         -2.530612                 -1.845065  0.832181
# 35            -1.425202         -4.530612                 12.277384  1.607807
# 36            -1.131198          3.469388                  3.787589  0.417980
# 37            -1.425202         -4.530612                 12.277384 -1.294347
# 38             0.532099         -3.530612                  4.216160  0.196223
# 39             0.005790         -0.530612                 -7.967514  0.421830
# 40            -0.643917          3.469388                  3.787589 -0.861373
# 41            -0.543190          1.469388                 -6.089963  1.168177
# 42            -1.425202         -3.530612                  4.216160  0.432345
# 43             1.800665         -1.530612                 -5.906289 -1.563364
# 44            -1.425202         -3.530612                  4.216160  0.942059
# 45             5.080053          0.469388                 -8.028738 -1.601156
# 46             0.044818          1.469388                 -6.089963 -2.160814
# 47                  NaN               NaN                       NaN       NaN
# 48                  NaN               NaN                       NaN       NaN
# 49             0.580985               NaN                       NaN       NaN
# 50                  NaN               NaN                       NaN       NaN
# 51                  NaN               NaN                       NaN       NaN
# 52                  NaN               NaN                       NaN       NaN
# 53            -0.543190         -0.530612                 -7.967514 -1.460024
# 54            -1.425202          3.469388                  3.787589 -0.873847
#
#      fd_mean  Composite_SubstanceXReward  Composite_SubstanceXReward_Squared  \
# 0   0.030117                   -0.191576                            3.342227
# 1   0.105981                   -0.421580                            3.234266
# 2  -0.474856                   -1.057953                            1.704889
# 3  -0.870765                    0.157611                            2.905903
# 4   0.036518                   -2.104785                            0.782022
# 5   0.055851                   -5.555724                           11.050575
# 6   0.495952                   -3.961993                           -5.466314
# 7  -1.066111                    6.014421                          -26.029944
# 8  -1.317167                   -3.892357                          -12.193833
# 9   0.215301                   -8.904970                           33.101678
# 10 -0.756184                   -4.367181                          -10.391444
# 11 -0.103825                   -0.331943                            3.497689
# 12 -0.202612                    0.388796                            1.951821
# 13 -1.037998                    3.298108                           12.461692
# 14  2.921899                    0.931986                           -0.254195
# 15  1.029422                    6.015475                           32.088110
# 16 -0.754424                   -0.709772                            4.167612
# 17  1.092103                   -2.327153                           -3.313794
# 18 -0.944581                   -3.961993                           -5.466314
# 19  0.820356                   -0.524769                            3.103678
# 20 -0.161144                   -0.961223                            4.018176
# 21 -0.108177                    3.164017                           -5.902600
# 22 -1.141454                    2.073420                           14.469537
# 23 -0.313432                    0.001608                            2.988680
# 24 -0.262262                    2.420007                           -4.019798
# 25  1.671487                    4.682402                          -19.995084
# 26  1.187733                   -0.556035                            3.511409
# 27 -0.224880                    3.975508                           22.970705
# 28 -0.300417                    0.863879                            3.837645
# 29 -0.169604                   -1.672779                            1.416806
# 30  2.670892                   -0.692496                            2.107585
# 31  0.819021                   -0.761220                            3.712050
# 32 -0.766803                    2.203421                            4.466409
# 33 -0.172097                    1.366257                           -3.162041
# 34  0.738754                    2.420007                           -4.019798
# 35 -1.436902                    6.014421                          -26.029944
# 36 -1.358877                   -4.367181                          -10.391444
# 37  1.279608                    6.014421                          -26.029944
# 38  0.513570                   -2.321253                            9.857127
# 39 -0.748219                   -0.445689                            3.226022
# 40  0.008779                   -2.676615                           -4.526216
# 41 -0.443655                   -1.240773                            2.051590
# 42 -0.245945                    4.589219                          -14.541070
# 43  1.778171                   -3.198736                            7.442942
# 44 -1.900885                    4.589219                          -14.541070
# 45 -0.249590                    1.941898                            4.343653
# 46  1.037055                   -0.376761                            3.321159
# 47       NaN                         NaN                                 NaN
# 48       NaN                         NaN                                 NaN
# 49       NaN                   -0.316299                                 NaN
# 50       NaN                         NaN                                 NaN
# 51       NaN                         NaN                                 NaN
# 52       NaN                         NaN                                 NaN
# 53  0.981210                   -0.154394                            3.071457
# 54 -0.076958                   -5.387195                          -13.930269
#
#     Unnamed: 11  Unnamed: 12  fd_mean.1
# 0           NaN          NaN  -0.334966
# 1           NaN          NaN   1.517712
# 2           NaN          NaN  -0.364555
# 3           NaN          NaN  -0.883898
# 4           NaN          NaN  -0.290715
# 5           NaN          NaN   0.600550
# 6           NaN          NaN   1.575204
# 7           NaN          NaN  -0.500486
# 8           NaN          NaN  -1.249693
# 9           NaN          NaN   0.048934
# 10          NaN          NaN  -0.862482
# 11          NaN          NaN  -0.010148
# 12          NaN          NaN   0.418005
# 13          NaN          NaN  -1.082686
# 14          NaN          NaN   2.743835
# 15          NaN          NaN   0.897171
# 16          NaN          NaN  -0.764871
# 17          NaN          NaN   1.480574
# 18          NaN          NaN   0.006603
# 19          NaN          NaN  -0.303872
# 20          NaN          NaN  -1.251559
# 21          NaN          NaN  -0.540060
# 22          NaN          NaN  -0.524767
# 23          NaN          NaN   1.050020
# 24          NaN          NaN  -0.508952
# 25          NaN          NaN  -0.320873
# 26          NaN          NaN   1.426223
# 27          NaN          NaN  -0.706137
# 28          NaN          NaN   2.058890
# 29          NaN          NaN   0.096755
# 30          NaN          NaN  -0.197272
# 31          NaN          NaN   0.740366
# 32          NaN          NaN  -1.198608
# 33          NaN          NaN  -1.101942
# 34          NaN          NaN   0.694740
# 35          NaN          NaN  -0.748881
# 36          NaN          NaN  -0.129887
# 37          NaN          NaN  -0.083709
# 38          NaN          NaN  -0.382951
# 39          NaN          NaN  -0.267491
# 40          NaN          NaN   0.340697
# 41          NaN          NaN  -1.692667
# 42          NaN          NaN   1.106793
# 43          NaN          NaN   0.250391
# 44          NaN          NaN        NaN
# 45          NaN          NaN        NaN
# 46          NaN          NaN        NaN
# 47          NaN          NaN        NaN
# 48          NaN          NaN        NaN
# 49          NaN          NaN        NaN
# 50          NaN          NaN        NaN
# 51          NaN          NaN        NaN
# 52          NaN          NaN        NaN
# 53          NaN          NaN  -0.096688
# 54          NaN          NaN   2.245947
