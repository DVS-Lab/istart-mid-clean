# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

# %%
test_load=nib.load('../masks/mean_func.nii.gz').get_fdata()
mask_load=nib.load('../masks/seed-VS.nii.gz').get_fdata()
test_load.shape
# Out:
# (65, 77, 65)

# %%
test=test_load[:,:,25]
mask=mask_load[:,:,25]
# Image
plt.imshow(test,cmap='gray')
# Add an overlay
plt.imshow(mask, cmap='jet', alpha=0.5)
plt.show()

# %%
for i in range(5):
    plt.subplot(5,5,i + 1)
    plt.imshow(test_load[:,:,22+i],'gray')
    plt.imshow(mask_load[:,:,22+i],'jet',alpha=0.5)
    plt.gcf().set_size_inches(10,10)
plt.show()
